# %%
#importing the libraries needed 
import pandas as pd
import requests, lxml, urllib.parse
from bs4 import BeautifulSoup

# %%
user_input=input("Enter content to search: ")
print("Gooooogling.....")
google_search=requests.get(f'https://www.google.com/search?q='+user_input).text
#print(google_search)
#Parsing the HTML content
soup = BeautifulSoup(google_search,'html.parser')
print(soup.prettify())

table = soup.find_all('div',attrs = {'class':'DUkiH cu-container'})
print(table)
# Out:
# Enter content to search: samsung mobile
# Gooooogling.....
# <!DOCTYPE html>
# <html lang="en-IN">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/>
#   <title>
#    samsung mobile - Google Search
#   </title>
#   <script nonce="werSyRiFxMeDZXjKL9Fvqw==">
#    (function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"==c||"q"==c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!=document.documentElement;a=a.parentElement)if("A"==a.tagName){a="1"==a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){
# ...

# %%
#copy_list=[]
user_input=input("Enter content to search: ")
print("Gooooogling.....")
headers = {
    "User-Agent":
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3538.102 Safari/537.36 Edge/18.19582"
}

# Search query
#params = {'q': 'samsung mobile'}
#google_search=requests.get("https://www.google.com/search?source=hp&ei=_KG8X5LULNv8rQHU_SY&q=samsung+mobile&oq=samsung+mob&gs_lcp=&sclient=psy-ab")
google_search=requests.get('https://google.com/search?q='+user_input).text
#print(google_search)

soup=BeautifulSoup(google_search,'lxml')


# Looking for container that has all necessary data findAll() or find_all()
for container in soup.findAll('div', class_=''):
    title = container.text
    print(title)
# Out:
# Enter content to search: samsung mobile
# Gooooogling.....

# %%
from bs4 import BeautifulSoup
import requests, lxml

headers = {
  "User-Agent":
  "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.102 Safari/537.36 Edge/18.19582"
}

html = requests.get('https://www.google.com/search?q=samsung mobile', headers=headers).text
soup = BeautifulSoup(html, 'lxml')

for ads in soup.select('.uEierd'):
    title = ads.select_one('.v0nnCb').text
    if ads.select_one('.WZ8Tjf span'):
        phone = ads.select_one('.WZ8Tjf span').text
    else:
        phone = None
    link = ads.select_one('.Krnil')['href']
    displayed_link = ads.select_one('.abuKkc .qzEoUe').text
    tracking_link = ads.select_one('.Krnil')['data-rw']
    snippet = ads.select_one('.uUPGi div:nth-child(3) .lyLwlc').text

    if ads.select_one('.aLF0Z'):
        inline_ads = ads.select_one('.aLF0Z').text.replace(" · ", "\n")
        inline_ads_link = ads.select_one('.aLF0Z a')['href']
    else:
        inline_ads = None
        inline_ads_link = None

print(f'{title}\n{link}\n{displayed_link}\n{tracking_link}\n{phone}\n{inline_ads}\n{inline_ads_link}\n')
# Out:
# Smartphones at Amazon - Best Deals on Phones & Tablets
# https://www.amazon.in/samsung-mobile/s?k=samsung+mobile
# http://www.amazon.in/
# https://www.google.com/aclk?sa=L&ai=DChcSEwiBypypksXyAhWPQ2AKHYCSBycYABAiGgJ0bQ&sig=AOD64_1tfJiXQZQ3VFugZ3UkGD4oBE0oAQ&q&adurl
# None
# None
# None

# %%
//*[@class="mnr-c pla-unit"][2]
